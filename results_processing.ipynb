BPRMF	0.06454762403291081	0.0447008547008547	0.0682512232333715	0.0006370839313073473	3.926102969791008	1170.0	30.0\
"

ciao_results = [
    ["MSE", 0.0007419224474007365, 0.0010531154381152596, 4.613781340086595],
    ["BCE", 0.05548592967980229, 0.000589572294506957, 3.7706456085727904],
    ["MSE-DOT", 0.001051400958493668, 0.003905972829792548, 6.567761326212736],
    ["BCE-DOT", 0.04390873396082842, 0.007338777355057613, 5.693946777866123],
    ["Random", 0.0001681858369007687, 0.38403496725957853, 12.935279224299107],
    ["MostPop", 0.06763633195476688, 0.000617824013097068, 3.8614812095954596],
    ["ItemKNN", 0.040231042934687544, 0.12318015124841553, 10.56428939033054],
    ["UserKNN", 0.03806226156278221, 0.0697652679474946, 10.003397565069083],
    ["BPRMF", 0.06454762403291081 , 0.0006370839313073473, 3.926102969791008]
]

# %%
lastfm_results_txt = "model	nDCG	Precision	Recall	Gini	SEntropy	UserCoverage	ItemCoverage\
MSE	0.004757925553860791	0.004575163398692811	0.000378655819935438	0.0003153869200160919	4.741709096008368	153.0	38.0\
BCE	0.03995	0.1098	0.00452	0.00023	4.34265	153	44\
MSE-DOT	0.00158	0.00654	0.00029	0.00205	7.43061	153	274\
BCE-DOT	0.00486	0.0183	0.00069	0.01806	10.26565	153	1311\
Random	0.001202863690764217	0.003921568627450981	0.00011566835975853398	0.023511109625480753	10.552185365681636	153.0	1510.0\
MostPop	0.06945039882241741	0.17647058823529413	0.0074660265504176366	0.0002875107192348292	4.635658276957565	153.0	41.0\
ItemKNN	0.2581731938703163	0.4921568627450981	0.022998908666377698	0.006812501908622037	8.99440676359538	153.0	742.0\
UserKNN	0.17254195872997263	0.31960784313725493	0.01456465804681686	0.0038123954384545744	8.041180812593234	153.0	545.0\
BPRMF	0.07068623166869804	0.16535947712418303	0.007042586871860154	0.0007409374491894605	5.830010780878694	153.0	191.0"

lastfm_results = [
    ["MSE", 0.004757925553860791, 0.0003153869200160919, 4.741709096008368],
    ["BCE", 0.03995, 0.00023, 4.34265],
    ["MSE-DOT", 0.00158, 0.00205,  7.43061],
    ["BCE-DOT", 0.00486, 0.01806, 10.26565],
    ["Random", 0.001202863690764217, 0.023511109625480753, 10.552185365681636],
    ["MostPop", 0.06945039882241741, 0.0002875107192348292, 4.635658276957565],
    ["ItemKNN", 0.2581731938703163, 0.006812501908622037, 8.99440676359538],
    ["UserKNN", 0.17254195872997263, 0.0038123954384545744, 8.041180812593234],
    ["BPRMF", 0.07068623166869804, 0.0007409374491894605, 5.830010780878694]
]

# %%
epinions_results_df = pd.DataFrame(epinions_results, columns=['Approach', 'nDCG', 'Gini Index', 'Entropy'])
ciao_results_df = pd.DataFrame(ciao_results, columns=['Approach', 'nDCG', 'Gini Index', 'Entropy'])
lastfm_results_df = pd.DataFrame(lastfm_results, columns=['Approach', 'nDCG', 'Gini Index', 'Entropy'])

# %%
print(epinions_results_df)
# Out:
#   Approach      nDCG  Gini Index    Entropy
# 0      MSE  0.000275    0.000361   3.332112
# 1      BCE  0.006609    0.000784   4.333990
# 2  MSE-DOT  0.001108    0.008364   8.110861
# 3  BCE-DOT  0.000374    0.054321  10.726677
# 4   Random  0.000173    0.327514  13.157971
# 5  MostPop  0.013718    0.000379   3.502579
# 6  ItemKNN  0.002126    0.153105  12.123291
# 7  UserKNN  0.018170    0.065962  10.600922
# 8    BPRMF  0.014558    0.021129   0.000643

# %%
print(ciao_results_df)
# Out:
#   Approach      nDCG  Gini Index    Entropy
# 0      MSE  0.000742    0.001053   4.613781
# 1      BCE  0.055486    0.000590   3.770646
# 2  MSE-DOT  0.001051    0.003906   6.567761
# 3  BCE-DOT  0.043909    0.007339   5.693947
# 4   Random  0.000168    0.384035  12.935279
# 5  MostPop  0.067636    0.000618   3.861481
# 6  ItemKNN  0.040231    0.123180  10.564289
# 7  UserKNN  0.038062    0.069765  10.003398
# 8    BPRMF  0.064548    0.000637   3.926103

# %%
print(lastfm_results_df)
# Out:
#   Approach      nDCG  Gini Index    Entropy
# 0      MSE  0.004758    0.000315   4.741709
# 1      BCE  0.039950    0.000230   4.342650
# 2  MSE-DOT  0.001580    0.002050   7.430610
# 3  BCE-DOT  0.004860    0.018060  10.265650
# 4   Random  0.001203    0.023511  10.552185
# 5  MostPop  0.069450    0.000288   4.635658
# 6  ItemKNN  0.258173    0.006813   8.994407
# 7  UserKNN  0.172542    0.003812   8.041181
# 8    BPRMF  0.070686    0.000741   5.830011

# %%
sns.set_style("whitegrid")
sns.set(font_scale=1.1)
ax = sns.scatterplot(data=epinions_results_df, x="nDCG", y="Entropy", hue="Approach", style="Approach", s=500, legend = False)

# %%
ax = sns.scatterplot(data=ciao_results_df, x="nDCG", y="Entropy", hue="Approach", style="Approach", s=500, legend = False)

# %%
import os
os.getcwd()
# Out:
# '/home/tduricic/Development/workspace/original-repos/GraphRec-WWW19'

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 3.5))
sns.scatterplot(ax=axes[0], data=epinions_results_df, x="nDCG", y="Gini Index", hue="Approach", style="Approach", s=500, legend = False)
axes[0].title.set_text('Epinions')
sns.scatterplot(ax=axes[1], data=ciao_results_df, x="nDCG", y="Gini Index", hue="Approach", style="Approach", s=500, legend = False)
axes[1].title.set_text('Ciao')
axes[1].set(ylabel=None)
sns.scatterplot(ax=axes[2], data=lastfm_results_df, x="nDCG", y="Gini Index", hue="Approach", style="Approach", s=500)
axes[2].title.set_text('Last.fm')
axes[2].set(ylabel=None)
sns.move_legend(axes[2], "upper left", bbox_to_anchor=(1, 1))
plt.savefig("./plots/ndcg_gi.pdf", format="pdf", bbox_inches="tight")

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 3.5))
sns.scatterplot(ax=axes[0], data=epinions_results_df, x="nDCG", y="Entropy", hue="Approach", style="Approach", s=500, legend = False)
axes[0].title.set_text('Epinions')
sns.scatterplot(ax=axes[1], data=ciao_results_df, x="nDCG", y="Entropy", hue="Approach", style="Approach", s=500, legend = False)
axes[1].title.set_text('Ciao')
axes[1].set(ylabel=None)
sns.scatterplot(ax=axes[2], data=lastfm_results_df, x="nDCG", y="Entropy", hue="Approach", style="Approach", s=500)
axes[2].title.set_text('Last.fm')
axes[2].set(ylabel=None)
sns.move_legend(axes[2], "upper left", bbox_to_anchor=(1, 1))
plt.savefig("./plots/entropy.pdf", format="pdf", bbox_inches="tight")
